# %%
import pandas as pd

# Load data from Excel files
carbon_emissions_df = pd.read_csv('dataset/carbon_emissions.csv')
cost_profiles_df = pd.read_csv('dataset/cost_profiles.csv')
demand_df = pd.read_csv('dataset/demand.csv')
fuels_df = pd.read_csv('dataset/fuels.csv')
vehicles_df = pd.read_csv('dataset/vehicles.csv')
vehicles_fuels_df = pd.read_csv('dataset/vehicles_fuels.csv')

# %%
carbon_emissions_df.head()
# Out:
#    Year  Carbon emission CO2/kg
# 0  2023                11677957
# 1  2024                10510161
# 2  2025                 9459145
# 3  2026                 8513230
# 4  2027                 7661907

# %%
cost_profiles_df.head()
# Out:
#    End of Year  Resale Value %  Insurance Cost %  Maintenance Cost %
# 0            1              90                 5                   1
# 1            2              80                 6                   3
# 2            3              70                 7                   5
# 3            4              60                 8                   7
# 4            5              50                 9                   9

# %%
demand_df.head()
# Out:
#    Year Size Distance  Demand (km)
# 0  2023   S1       D1       869181
# 1  2023   S1       D2      2597094
# 2  2023   S1       D3      3292011
# 3  2023   S1       D4       414315
# 4  2023   S2       D1       995694

# %%
fuels_df.head()
# Out:
#   Fuel  Year  Emissions (CO2/unit_fuel)  Cost ($/unit_fuel)  \
# 0  B20  2023                    3.04858            1.220845
# 1  B20  2024                    3.04858            1.246802
# 2  B20  2025                    3.04858            1.273310
# 3  B20  2026                    3.04858            1.300382
# 4  B20  2027                    3.04858            1.328030
#
#    Cost Uncertainty (±%)
# 0                      0
# 1                      2
# 2                      4
# 3                      6
# 4                      8

# %%
# print(vehicles_df['ID'].nunique())
# print(vehicles_df.shape)
vehicles_df.head(200)
# Out:
#               ID Vehicle Size  Year  Cost ($)  Yearly range (km) Distance
# 0    BEV_S1_2023     BEV   S1  2023    187000             102000       D1
# 1    BEV_S1_2024     BEV   S1  2024    177650             102000       D1
# 2    BEV_S1_2025     BEV   S1  2025    168767             102000       D1
# 3    BEV_S1_2026     BEV   S1  2026    160329             102000       D2
# 4    BEV_S1_2027     BEV   S1  2027    152312             102000       D2
# ..           ...     ...  ...   ...       ...                ...      ...
# 187  LNG_S3_2034     LNG   S3  2034    209208              73000       D4
# 188  LNG_S3_2035     LNG   S3  2035    215484              73000       D4
# 189  LNG_S3_2036     LNG   S3  2036    221948              73000       D4
# 190  LNG_S3_2037     LNG   S3  2037    228607              73000       D4
# 191  LNG_S3_2038     LNG   S3  2038    235465              73000       D4
#
# [192 rows x 7 columns]

# %%
pd.set_option('display.max_rows', 500)

# %%
# print(vehicles_fuels_df.groupby(['ID'])['Fuel'].nunique())
vehicles_fuels_df.head()
# Out:
#             ID         Fuel  Consumption (unit_fuel/km)
# 0  BEV_S1_2023  Electricity                    0.893043
# 1  BEV_S1_2024  Electricity                    0.893043
# 2  BEV_S1_2025  Electricity                    0.893043
# 3  BEV_S1_2026  Electricity                    0.893043
# 4  BEV_S1_2027  Electricity                    0.868161

# %%
import gurobipy as gp
from gurobipy import GRB

# Create Gurobi model
model = gp.Model("FleetDecarbonization")

# Define sets
vehicles = vehicles_df['ID'].unique() #vehicles
years = list(range(2023, 2039)) #years
fuels = fuels_df['Fuel'].unique() #type of fuels
sizes = ["S1", "S2", "S3", "S4"]  #size buckets
distances = ["D1", "D2", "D3", "D4"]  #distance buckets

# %%
# Parameters
demand = {(y, s, d): demand_df[(demand_df['Year']==y)&(demand_df['Size']==s)&(demand_df['Distance']==d)]['Demand (km)'].values[0] for y in years for s in sizes for d in distances}
vehicle_cost = {v: vehicles_df[vehicles_df['ID']==v]["Cost ($)"].values[0] for v in vehicles}
vehicle_range = {v: vehicles_df[vehicles_df['ID']==v]["Yearly range (km)"].values[0] for v in vehicles}
vehicle_size = {v: vehicles_df[vehicles_df['ID']==v]["Size"].values[0] for v in vehicles}
vehicle_distance = {v: vehicles_df[vehicles_df['ID']==v]["Distance"].values[0] for v in vehicles}
fuel_set = {v: list(vehicles_fuels_df[vehicles_fuels_df['ID']==v]['Fuel'].unique()) for v in vehicles}
fuel_consumption = {(v, f): vehicles_fuels_df[(vehicles_fuels_df['ID']==v)&(vehicles_fuels_df['Fuel']==f)]['Consumption (unit_fuel/km)'].values[0] for v in vehicles for f in fuel_set[v]}
fuel_cost = {(y, f): fuels_df[(fuels_df['Year']==y)&(fuels_df['Fuel']==f)]["Cost ($/unit_fuel)"].values[0] for y in years for f in fuels}
fuel_emissions = {(y, f): fuels_df[(fuels_df['Fuel']==f)&(fuels_df['Year']==y)]["Emissions (CO2/unit_fuel)"].values[0] for f in fuels for y in years}
carbon_budget = {y: carbon_emissions_df[carbon_emissions_df['Year']==y]['Carbon emission CO2/kg'].values[0] for y in years}
resale_value = {1: 0.9, 2: 0.8, 3: 0.7, 4: 0.6, 5: 0.5, 6: 0.4, 7: 0.3, 8: 0.3, 9: 0.3, 10: 0.3}
insurance_cost = {1: 0.05, 2: 0.06, 3: 0.07, 4: 0.08, 5: 0.09, 6: 0.10, 7: 0.11, 8: 0.12, 9: 0.13, 10: 0.14}
maintenance_cost = {1: 0.01, 2: 0.03, 3: 0.05, 4: 0.07, 5: 0.09, 6: 0.11, 7: 0.13, 8: 0.15, 9: 0.17, 10: 0.19}
vehile_size_map = {(v, s): vehicles_df[(vehicles_df['ID']==v)&(vehicles_df['Size']==s)]['Size'].count() for v in vehicles for s in sizes}
distance_bucket_map = {"D1": 300, "D2": 400, "D3": 500, "D4": 600}
vehicle_not_my_fuels = {v: list(set(fuels) ^ set(fuel_set[v])) for v in vehicles}

# %% [markdown]
# ## Define the Objective Function

# %%
import re

def get_y_purchase(vehicle_id):
    match = re.search(r'(\d{4})$', vehicle_id)
    if match:
        return int(match.group(1))

get_y_purchase('BEV_S1_2025')
# Out:
# 2025

# %%
def cardinality(demand):
    num = re.search(r'(\d{1})$', demand)
    if num:
        return int(num.group(1))
cardinality('D1')
# Out:
# 1

# %%
m = gp.Model("Fleet Decarbonization")
buy = m.addVars(vehicles, vtype=GRB.INTEGER, name="buy") #number of vehicles bought
# use = m.addVars(vehicles, years, vtype=GRB.CONTINUOUS, name="use") 
sell = m.addVars(vehicles, years, vtype=GRB.INTEGER, name="sell")
vehicle_list = m.addVars(vehicles, years, vtype=GRB.INTEGER, name="vehicle_list") #number of vehicles in year y
vehicle_list_fuels = m.addVars(vehicles, years, fuels, distances, vtype=GRB.INTEGER, name="vehicle_list_fuels") #N_v_f
distance = m.addVars(vehicles, years, fuels, distances, vtype=GRB.CONTINUOUS, name="distance")                  

# Objective
m.setObjective(
    gp.quicksum(buy[v] * vehicle_cost[v] for v in vehicles)
    + gp.quicksum(vehicle_cost[v] * resale_value[y - get_y_purchase(v) + 1] * sell[v, y] 
               + vehicle_cost[v] * insurance_cost[y - get_y_purchase(v)+ 1] * vehicle_list[v,y]
               + vehicle_cost[v] * maintenance_cost[y - get_y_purchase(v) + 1] * vehicle_list[v,y]
               for y in years for v in vehicles if ((y >= get_y_purchase(v)) & (y - get_y_purchase(v) <=9)))
    + gp.quicksum(vehicle_list_fuels[v, y, f, d] * distance[v, y, f, d] * fuel_consumption[v, f] * fuel_cost[y, f] 
               for y in years for v in vehicles for f in fuel_set[v] for d in distances),
    GRB.MINIMIZE
)

# %%
m.addConstrs(
    (vehicle_list_fuels[v, y, f, d] == 0 for y in years for f in fuels for d in distances for v in vehicles if distance_bucket_map[vehicle_distance[v]] < distance_bucket_map[d]),
    "Use Variable constraint"
)
m.addConstrs(
    (distance[v, y, f, d] == 0 for f in fuels for y in years for d in distances for v in vehicles if distance_bucket_map[vehicle_distance[v]] < distance_bucket_map[d]),
    "Distance constraint"
)
m.addConstrs(
    (vehicle_list_fuels[v, y, f, d] == 0 for v in vehicles for y in years for f in vehicle_not_my_fuels[v] for d in distances),
    "Use Variable constraint for Fuel Set"
)
m.addConstrs(
    (distance[v, y, f, d] == 0 for v in vehicles for y in years for f in vehicle_not_my_fuels[v] for d in distances),
    "Distance constraint for Fuel Set"
)
m.addConstrs(
    (vehicle_list_fuels[v, y, f, d] == 0 for v in vehicles for y in years for f in fuels for d in distances if ((y < get_y_purchase(v)) | (y - get_y_purchase(v) > 9))),
    "Use Variable constraint for Year Set"
)
m.addConstrs(
    (distance[v, y, f, d] == 0 for v in vehicles for y in years for f in fuels for d in distances if ((y < get_y_purchase(v)) | (y - get_y_purchase(v) > 9))),
    "Distance constraint for Year Set"
)
m.addConstrs(
    (vehicle_list_fuels[v, y, f, d]*vehicle_range[v] >= distance[v, y, f, d] for y in years for f in fuels for d in distances for v in vehicles),
    "Use Variable constraint for Distance"
)
m.addConstrs(
    (gp.quicksum(vehicle_list_fuels[v, y, f, d] * distance[v, y, f, d] * vehile_size_map[v, s] for v in vehicles for f in fuel_set[v]) >= demand[y, s, d] for y in years for s in sizes for d in distances),
    "Demand satisfaction constraint"
)
m.addConstrs(
    (gp.quicksum(vehicle_list_fuels[v, y, f, d] * distance[v, y, f, d] * fuel_consumption[v, f] * fuel_emissions[y, f] for v in vehicles for f in fuel_set[v] for d in distances) <= carbon_budget[y] for y in years),
    "Carbon Emission Satisfaction constraint"
)
m.addConstrs(
    (gp.quicksum(sell[v, y] for y in years if ((y <= get_y_purchase(v) - 1) | (y - get_y_purchase(v) >= 10))) == 0 for v in vehicles),
    "Selling constraint"
)
m.addConstrs(
    (gp.quicksum(sell[v, y] for y in range(2023,2030) if ((y >= get_y_purchase(v)) & (y - get_y_purchase(v) <= 9))) == buy[v] for v in vehicles),
    "Vehicle Mass Balance for 10 Years"
)
m.addConstrs(
    (gp.quicksum(sell[v, y] for y in range(2030,2039) if ((y >= get_y_purchase(v)) & (y - get_y_purchase(v) <= 9))) == buy[v] for v in vehicles),
    "Vehicle Mass Balance for less than 10 Years"
)
m.addConstrs(
    ((gp.quicksum(sell[v, y] for v in vehicles)) <= 0.2 * (gp.quicksum(vehicle_list[v, y] for v in vehicles)) for y in years),
    "Selling Yearly Limit"
)
m.addConstrs(
    (buy[v]>=0 for v in vehicles),
    "Buy >= 0"
)
m.addConstrs(
    (sell[v, y]>=0 for y in years for v in vehicles),
    "Selling >=0"
)
m.addConstrs(
    (vehicle_list_fuels[v, y, f, d]>=0 for y in years for v in vehicles for d in distances for f in fuels),
    "Using List >=0"
)
m.addConstrs(
    (distance[v, y, f, d]>=0 for v in vehicles for y in years for d in distances for f in fuels),
    "Distance List >=0"
)
m.addConstrs(
    (vehicle_list[v, y]>=0 for y in years for v in vehicles),
    "Number of Vehicles >=0"
)
# m.addConstrs(
#     ((buy[v] - (gp.quicksum(sell[v, y] for y in years if ((y >= get_y_purchase(v)) & (y <= j - 1))))) == vehicle_list[v, j] for v in vehicles for j in years),
#     "Buy Sell Equality"
# )
m.addConstrs(
    (vehicle_list[v, y]>=0 for y in years for v in vehicles),
    "Number of Vehicles >=0"
)
m.addConstrs(
    (gp.quicksum(distance[v, y, f, d] for f in fuels for d in distances) <= vehicle_range[v] for v in vehicles for y in years),
    "Yearly Range"
)
m.addConstrs(
    (gp.quicksum(vehicle_list_fuels[v, y, f, d] for f in fuel_set[v] for d in distances) <= vehicle_list[v, y] for v in vehicles for y in years),
    "Additonal Use Balance"
)

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12700, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 361392 rows, 129216 columns and 509188 nonzeros
# Model fingerprint: 0x8ba443fd
# Model has 20480 quadratic objective terms
# Model has 272 quadratic constraints
# Variable types: 61440 continuous, 67776 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+05]
#   QMatrix range    [6e-02, 1e+00]
#   Objective range  [5e+03, 4e+05]
#   QObjective range [2e-01, 8e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+04, 1e+05]
#   QRHS range       [2e+03, 1e+07]
# Presolve removed 351544 rows and 87824 columns
# Presolve time: 0.14s
# Presolved: 44089 rows, 49886 columns, 109625 nonzeros
# Presolved model has 8492 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
#
# Solving non-convex MIQCP
#
# Variable types: 28974 continuous, 20912 integer (0 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.923979e+07, 112 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.9240e+07    0  512          - 7.9240e+07      -     -    1s
#      0     0 7.9472e+07    0  662          - 7.9472e+07      -     -    1s
#      0     0 7.9555e+07    0  757          - 7.9555e+07      -     -    1s
#      0     0 7.9557e+07    0  759          - 7.9557e+07      -     -    1s
#      0     0 7.9659e+07    0 1098          - 7.9659e+07      -     -    1s
#      0     0 7.9700e+07    0  915          - 7.9700e+07      -     -    1s
#      0     0 7.9776e+07    0 1139          - 7.9776e+07      -     -    2s
#      0     0 7.9796e+07    0  975          - 7.9796e+07      -     -    2s
#      0     0 7.9829e+07    0 1064          - 7.9829e+07      -     -    2s
#      0     0 7.9836e+07    0 1081          - 7.9836e+07      -     -    2s
#      0     0 8.0023e+07    0  628          - 8.0023e+07      -     -    2s
#      0     0 8.0033e+07    0  584          - 8.0033e+07      -     -    2s
#      0     0 8.0072e+07    0  680          - 8.0072e+07      -     -    2s
#      0     0 8.0074e+07    0  680          - 8.0074e+07      -     -    2s
#      0     0 8.0096e+07    0  715          - 8.0096e+07      -     -    2s
#      0     0 8.0096e+07    0  715          - 8.0096e+07      -     -    3s
#      0     0 8.0111e+07    0  782          - 8.0111e+07      -     -    3s
#      0     0 8.0113e+07    0  763          - 8.0113e+07      -     -    3s
#      0     0 8.0128e+07    0  919          - 8.0128e+07      -     -    3s
#      0     0 8.0129e+07    0  914          - 8.0129e+07      -     -    3s
#      0     0 8.0143e+07    0  809          - 8.0143e+07      -     -    3s
#      0     0 8.0143e+07    0  810          - 8.0143e+07      -     -    3s
#      0     0 8.0158e+07    0  755          - 8.0158e+07      -     -    3s
#      0     0 8.0159e+07    0  747          - 8.0159e+07      -     -    3s
#      0     0 8.0169e+07    0  863          - 8.0169e+07      -     -    3s
#      0     0 8.0171e+07    0  849          - 8.0171e+07      -     -    3s
#      0     0 8.0181e+07    0  807          - 8.0181e+07      -     -    4s
#      0     0 8.0181e+07    0  801          - 8.0181e+07      -     -    4s
#      0     0 8.0190e+07    0  929          - 8.0190e+07      -     -    4s
#      0     0 8.0190e+07    0  931          - 8.0190e+07      -     -    4s
#      0     0 8.0198e+07    0  874          - 8.0198e+07      -     -    4s
#      0     0 8.0198e+07    0  863          - 8.0198e+07      -     -    4s
#      0     0 8.0204e+07    0  959          - 8.0204e+07      -     -    4s
#      0     0 8.0205e+07    0  939          - 8.0205e+07      -     -    4s
#      0     0 8.0211e+07    0  943          - 8.0211e+07      -     -    4s
#      0     0 8.0211e+07    0  955          - 8.0211e+07      -     -    4s
#      0     0 8.0217e+07    0  894          - 8.0217e+07      -     -    4s
#      0     0 8.0217e+07    0  886          - 8.0217e+07      -     -    5s
#      0     0 8.0222e+07    0  988          - 8.0222e+07      -     -    5s
#      0     0 8.0222e+07    0  984          - 8.0222e+07      -     -    5s
#      0     2 8.0222e+07    0  984          - 8.0222e+07      -     -    8s
#     15    28 8.0222e+07    4  989          - 8.0222e+07      -  11.3   10s
#    293   311 8.0227e+07   28  990          - 8.0223e+07      -  20.0   15s
#    615   657 8.0232e+07   52  958          - 8.0223e+07      -  18.2   20s
#    843   933 8.0235e+07   70  952          - 8.0223e+07      -  17.4   25s
#   1299  1399 8.0243e+07  111  932          - 8.0223e+07      -  16.2   30s
#   1713  1841 8.0250e+07  144  942          - 8.0223e+07      -  16.1   35s
#   2380  2523 8.0276e+07  191  941          - 8.0223e+07      -  15.6   41s
#   2814  2990 8.0391e+07  225  924          - 8.0223e+07      -  15.3   45s
#   3521  3716 8.0369e+07  292  882          - 8.0223e+07      -  15.0   51s
#   3911  4103 8.0372e+07  328  845          - 8.0223e+07      -  15.3   55s
#   4529  4715 8.0384e+07  379  814          - 8.0223e+07      -  15.7   60s
#   5132  5385 8.0392e+07  430  809          - 8.0223e+07      -  15.8   66s
#   5662  5948 8.0400e+07  471  797          - 8.0223e+07      -  15.7   71s
#   6224  6565 8.0454e+07  515  786          - 8.0223e+07      -  15.9   76s
#   6891  7215 8.0478e+07  568  763          - 8.0223e+07      -  15.7   82s
#   7214  7564 8.0503e+07  597  749          - 8.0223e+07      -  15.5   85s
#   7956  8217 8.0517e+07  656  725          - 8.0223e+07      -  15.2   93s
#   8216  8608 8.0520e+07  677  726          - 8.0223e+07      -  15.2   96s
#   8607  9037 8.0532e+07  705  726          - 8.0223e+07      -  15.2  100s
#   9037  9038 8.0686e+07  446 4246          - 8.0223e+07      -  15.2  328s
#   9043  9042 8.0470e+07  470  366          - 8.0223e+07      -  15.2  330s
#   9093  9075 8.0556e+07  641  584          - 8.0375e+07      -  15.1  335s
#   9145  9110 8.0462e+07  332  783          - 8.0462e+07      -  15.0  340s
#   9189  9139 8.0532e+07  138  646          - 8.0532e+07      -  15.0  345s
#   9230  9167 8.0568e+07  274  629          - 8.0568e+07      -  14.9  350s
#   9240  9175 8.0573e+07  582 4246          - 8.0573e+07      -  20.5  612s
#   9256  9186 8.0575e+07  542  653          - 8.0575e+07      -  20.5  615s
#   9283  9204 8.0593e+07  630  591          - 8.0593e+07      -  20.4  620s
#   9323  9230 8.0612e+07  208  582          - 8.0612e+07      -  20.3  625s
#   9361  9256 8.0627e+07  527  568          - 8.0627e+07      -  20.3  630s
#   9398  9280 8.0643e+07  111  609          - 8.0643e+07      -  20.2  635s
#   9433  9304 8.0654e+07   57  509          - 8.0654e+07      -  20.1  640s
#   9443  9312 8.0656e+07  470 4246          - 8.0656e+07      -  25.3  908s
#   9452  9318 8.0656e+07  479  759          - 8.0656e+07      -  25.2  910s
#   9483  9339 8.0661e+07  630  481          - 8.0661e+07      -  25.2  915s
#   9529  9369 8.0673e+07  605  464          - 8.0673e+07      -  25.0  920s
#   9575  9400 8.0686e+07  693  453          - 8.0686e+07      -  24.9  925s
#   9622  9431 8.0695e+07  509  405          - 8.0695e+07      -  24.8  930s
#   9646  9449 8.0805e+07  581 4246          - 8.0699e+07      -  27.7 1204s
#   9648  9450 8.0699e+07  683  256          - 8.0699e+07      -  27.7 1205s
#   9688  9477 8.0699e+07   51  342          - 8.0699e+07      -  27.6 1210s
#   9740  9513 8.0705e+07  582 4246          - 8.0705e+07      -  28.6 1496s
#   9763  9528 8.0705e+07  400  203          - 8.0705e+07      -  28.5 1500s
#   9795  9550 8.0706e+07  523  325          - 8.0706e+07      -  28.4 1508s
#   9796  9553 8.0706e+07   61  934          - 8.0706e+07      -  29.3 1510s
#   9966  9677 8.0709e+07   71  848          - 8.0709e+07      -  30.2 1515s
#  10091  9762 8.0769e+07   76  718          - 8.0713e+07      -  31.0 1520s
#  10298  9914 8.0719e+07   85  701          - 8.0719e+07      -  32.2 1525s
#  10644 10184 8.0765e+07  100  512          - 8.0727e+07      -  33.6 1530s
#  11128 10556 8.0739e+07  119  420          - 8.0727e+07      -  34.7 1535s
# H114382 94042                    9.108931e+07 8.0727e+07  11.4%  22.2 2863s
# H114383 94032                    9.108806e+07 8.0727e+07  11.4%  22.2 2863s
# H114472 94022                    9.108717e+07 8.0727e+07  11.4%  22.2 2863s
# H114570 93990                    9.108378e+07 8.0727e+07  11.4%  22.2 2863s
# H114802 93934                    9.107653e+07 8.0727e+07  11.4%  22.1 2863s
#  115350 95458 8.9717e+07 1401  279 9.1077e+07 8.0727e+07  11.4%  22.1 2883s
#  116938 96343 8.9822e+07 1420  279 9.1077e+07 8.0727e+07  11.4%  22.0 2899s
# H117001 96272                    9.106463e+07 8.0727e+07  11.4%  22.0 2899s
# H117492 95717                    9.100841e+07 8.0727e+07  11.3%  21.9 2900s
# H117863 97007                    9.100744e+07 8.0727e+07  11.3%  22.0 2919s
# H117953 96980                    9.100350e+07 8.0727e+07  11.3%  22.0 2919s
#  119202 97831 8.9975e+07 1472  273 9.1004e+07 8.0727e+07  11.3%  22.1 2935s
# H119283 97779                    9.099460e+07 8.0727e+07  11.3%  22.1 2935s
#  120099 99486 9.0184e+07 1485  272 9.0995e+07 8.0727e+07  11.3%  22.1 2957s
#  121902 100612 9.0632e+07 1522  273 9.0995e+07 8.0727e+07  11.3%  21.9 2974s
# H122133 100592                    9.099127e+07 8.0727e+07  11.3%  21.9 2974s
# H122561 100581                    9.098889e+07 8.0727e+07  11.3%  21.9 2974s
# H122935 100581                    9.098872e+07 8.0727e+07  11.3%  21.9 2975s
#  123074 101869 9.0565e+07 1530  276 9.0989e+07 8.0727e+07  11.3%  21.9 2994s
# H124516 103006                    9.098414e+07 8.0727e+07  11.3%  21.9 3010s
# H125709 104197                    9.098265e+07 8.0731e+07  11.3%  21.9 3034s
# H125891 104182                    9.097919e+07 8.0731e+07  11.3%  22.0 3034s
# H125892 104176                    9.097726e+07 8.0731e+07  11.3%  22.0 3034s
# H126017 104172                    9.097516e+07 8.0731e+07  11.3%  21.9 3034s
#  126902 105273 8.0755e+07  135  470 9.0975e+07 8.0731e+07  11.3%  21.9 3052s
# H126989 105237                    9.096181e+07 8.0731e+07  11.2%  21.9 3052s
# H128041 106110                    9.094858e+07 8.0731e+07  11.2%  21.9 3068s
# H128857 106099                    9.094619e+07 8.0731e+07  11.2%  21.9 3068s
# H128970 107457                    9.094400e+07 8.0731e+07  11.2%  21.9 3085s
# H129667 107182                    9.088971e+07 8.0731e+07  11.2%  21.8 3085s

# %%
obj = m.getObjective()
print(obj.getValue())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 2
#       1 obj = m.getObjective()
# ----> 2 print(obj.getValue())
#
# File src\\gurobipy\\quadexpr.pxi:414, in gurobipy.QuadExpr.getValue()
#
# File src\\gurobipy\\linexpr.pxi:396, in gurobipy.LinExpr.getValue()
#
# File src\\gurobipy\\var.pxi:125, in gurobipy.Var.__getattr__()
#
# File src\\gurobipy\\var.pxi:153, in gurobipy.Var.getAttr()
#
# File src\\gurobipy\\attrutil.pxi:103, in gurobipy._getattr()
#
# AttributeError: Unable to retrieve attribute 'x'

# %%
for v in m.getVars():
    if(v.X != 0):
        print(f"{v.VarName} = {v.X}")
# Out:
# vehicle_list_fuels[BEV_S1_2023,2024,Electricity,D1] = 9.0
# vehicle_list_fuels[BEV_S1_2023,2025,Electricity,D1] = 9.0
# vehicle_list_fuels[BEV_S1_2023,2026,Electricity,D1] = 18.0
# vehicle_list_fuels[BEV_S1_2026,2026,Electricity,D2] = 58.0
# vehicle_list_fuels[BEV_S1_2027,2027,Electricity,D1] = 20.0
# vehicle_list_fuels[BEV_S1_2027,2027,Electricity,D2] = 60.0
# vehicle_list_fuels[BEV_S1_2027,2028,Electricity,D1] = 20.0
# vehicle_list_fuels[BEV_S1_2027,2028,Electricity,D2] = 62.0
# vehicle_list_fuels[BEV_S1_2027,2029,Electricity,D1] = 10.0
# vehicle_list_fuels[BEV_S1_2027,2030,Electricity,D1] = 20.0
# vehicle_list_fuels[BEV_S1_2027,2030,Electricity,D2] = 58.0
# vehicle_list_fuels[BEV_S1_2027,2031,Electricity,D1] = 22.0
# vehicle_list_fuels[BEV_S1_2027,2031,Electricity,D2] = 33.0
# vehicle_list_fuels[BEV_S1_2027,2032,Electricity,D1] = 982.0
# vehicle_list_fuels[BEV_S1_2027,2032,Electricity,D2] = 34.0
# vehicle_list_fuels[BEV_S1_2027,2033,Electricity,D1] = 11.0
# vehicle_list_fuels[BEV_S1_2027,2034,Electricity,D1] = 11.0
# vehicle_list_fuels[BEV_S1_2027,2035,Electricity,D1] = 11.0
# vehicle_list_fuels[BEV_S1_2027,2036,Electricity,D1] = 796.0
# vehicle_list_fuels[BEV_S1_2027,2036,Electricity,D2] = 38.0
# vehicle_list_fuels[BEV_S1_2028,2031,Electricity,D1] = 10.0
# vehicle_list_fuels[BEV_S1_2028,2033,Electricity,D2] = 35.0
# vehicle_list_fuels[BEV_S1_2028,2037,Electricity,D1] = 24.0
# vehicle_list_fuels[BEV_S1_2028,2037,Electricity,D2] = 39.0
# vehicle_list_fuels[BEV_S1_2029,2029,Electricity,D2] = 1451.0
# vehicle_list_fuels[BEV_S1_2029,2029,Electricity,D3] = 39.0
# vehicle_list_fuels[BEV_S1_2029,2030,Electricity,D2] = 6.0
# vehicle_list_fuels[BEV_S1_2029,2030,Electricity,D3] = 55.0
# vehicle_list_fuels[BEV_S1_2029,2031,Electricity,D3] = 80.0
# vehicle_list_fuels[BEV_S1_2029,2032,Electricity,D3] = 84.0
# vehicle_list_fuels[BEV_S1_2029,2033,Electricity,D3] = 43.0
# vehicle_list_fuels[BEV_S1_2029,2034,Electricity,D3] = 44.0
# vehicle_list_fuels[BEV_S1_2029,2035,Electricity,D2] = 74.0
# vehicle_list_fuels[BEV_S1_2029,2035,Electricity,D3] = 88.0
# vehicle_list_fuels[BEV_S1_2029,2036,Electricity,D3] = 46.0
# vehicle_list_fuels[BEV_S1_2029,2037,Electricity,D3] = 46.0
# vehicle_list_fuels[BEV_S1_2029,2038,Electricity,D1] = 585.0
# vehicle_list_fuels[BEV_S1_2029,2038,Electricity,D2] = 40.0
# vehicle_list_fuels[BEV_S1_2030,2030,Electricity,D3] = 11.0
# vehicle_list_fuels[BEV_S1_2030,2038,Electricity,D3] = 96.0
# vehicle_list_fuels[BEV_S1_2031,2037,Electricity,D1] = 12.0
# vehicle_list_fuels[BEV_S1_2032,2032,Electricity,D4] = 12.0
# vehicle_list_fuels[BEV_S1_2032,2033,Electricity,D4] = 12.0
# vehicle_list_fuels[BEV_S1_2032,2034,Electricity,D2] = 67.0
# vehicle_list_fuels[BEV_S1_2032,2034,Electricity,D4] = 12.0
# vehicle_list_fuels[BEV_S1_2032,2035,Electricity,D4] = 222.0
# vehicle_list_fuels[BEV_S1_2032,2036,Electricity,D4] = 12.0
# vehicle_list_fuels[BEV_S1_2032,2037,Electricity,D4] = 14.0
# vehicle_list_fuels[BEV_S1_2032,2038,Electricity,D4] = 7.0
# vehicle_list_fuels[BEV_S2_2023,2024,Electricity,D1] = 10.0
# vehicle_list_fuels[BEV_S2_2023,2025,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S2_2023,2026,Electricity,D1] = 22.0
# vehicle_list_fuels[BEV_S2_2024,2025,Electricity,D1] = 9.0
# vehicle_list_fuels[BEV_S2_2025,2025,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S2_2026,2026,Electricity,D2] = 28.0
# vehicle_list_fuels[BEV_S2_2027,2027,Electricity,D1] = 22.0
# vehicle_list_fuels[BEV_S2_2027,2027,Electricity,D2] = 28.0
# vehicle_list_fuels[BEV_S2_2027,2028,Electricity,D1] = 22.0
# vehicle_list_fuels[BEV_S2_2027,2028,Electricity,D2] = 30.0
# vehicle_list_fuels[BEV_S2_2027,2029,Electricity,D1] = 12.0
# vehicle_list_fuels[BEV_S2_2027,2029,Electricity,D2] = 93.0
# vehicle_list_fuels[BEV_S2_2027,2030,Electricity,D1] = 30.0
# vehicle_list_fuels[BEV_S2_2027,2030,Electricity,D2] = 32.0
# vehicle_list_fuels[BEV_S2_2027,2031,Electricity,D1] = 24.0
# vehicle_list_fuels[BEV_S2_2027,2031,Electricity,D2] = 32.0
# vehicle_list_fuels[BEV_S2_2027,2032,Electricity,D1] = 34.0
# vehicle_list_fuels[BEV_S2_2027,2032,Electricity,D2] = 17.0
# vehicle_list_fuels[BEV_S2_2027,2033,Electricity,D1] = 26.0
# vehicle_list_fuels[BEV_S2_2027,2033,Electricity,D2] = 17.0
# vehicle_list_fuels[BEV_S2_2027,2034,Electricity,D1] = 26.0
# vehicle_list_fuels[BEV_S2_2027,2034,Electricity,D2] = 18.0
# vehicle_list_fuels[BEV_S2_2027,2035,Electricity,D1] = 324.0
# vehicle_list_fuels[BEV_S2_2027,2035,Electricity,D2] = 19.0
# vehicle_list_fuels[BEV_S2_2027,2036,Electricity,D1] = 28.0
# vehicle_list_fuels[BEV_S2_2027,2036,Electricity,D2] = 19.0
# vehicle_list_fuels[BEV_S2_2028,2029,Electricity,D2] = 8.0
# vehicle_list_fuels[BEV_S2_2028,2037,Electricity,D1] = 686.0
# vehicle_list_fuels[BEV_S2_2028,2037,Electricity,D2] = 20.0
# vehicle_list_fuels[BEV_S2_2029,2029,Electricity,D3] = 9.0
# vehicle_list_fuels[BEV_S2_2029,2030,Electricity,D3] = 9.0
# vehicle_list_fuels[BEV_S2_2029,2031,Electricity,D3] = 18.0
# vehicle_list_fuels[BEV_S2_2029,2032,Electricity,D3] = 10.0
# vehicle_list_fuels[BEV_S2_2029,2033,Electricity,D1] = 23.0
# vehicle_list_fuels[BEV_S2_2029,2033,Electricity,D3] = 20.0
# vehicle_list_fuels[BEV_S2_2029,2034,Electricity,D3] = 10.0
# vehicle_list_fuels[BEV_S2_2029,2035,Electricity,D3] = 20.0
# vehicle_list_fuels[BEV_S2_2029,2036,Electricity,D3] = 11.0
# vehicle_list_fuels[BEV_S2_2029,2037,Electricity,D3] = 22.0
# vehicle_list_fuels[BEV_S2_2029,2038,Electricity,D1] = 28.0
# vehicle_list_fuels[BEV_S2_2029,2038,Electricity,D2] = 352.0
# vehicle_list_fuels[BEV_S2_2029,2038,Electricity,D3] = 24.0
# vehicle_list_fuels[BEV_S2_2030,2034,Electricity,D1] = 13.0
# vehicle_list_fuels[BEV_S2_2032,2032,Electricity,D1] = 48.0
# vehicle_list_fuels[BEV_S2_2032,2032,Electricity,D4] = 2.0
# vehicle_list_fuels[BEV_S2_2032,2033,Electricity,D4] = 2.0
# vehicle_list_fuels[BEV_S2_2032,2034,Electricity,D4] = 4.0
# vehicle_list_fuels[BEV_S2_2032,2035,Electricity,D4] = 2.0
# vehicle_list_fuels[BEV_S2_2032,2036,Electricity,D2] = 15.0
# vehicle_list_fuels[BEV_S2_2032,2036,Electricity,D4] = 4.0
# vehicle_list_fuels[BEV_S2_2032,2037,Electricity,D4] = 6.0
# vehicle_list_fuels[BEV_S2_2032,2038,Electricity,D4] = 2.0
# vehicle_list_fuels[BEV_S4_2023,2024,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2023,2025,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2023,2026,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2026,2026,Electricity,D2] = 14.0
# vehicle_list_fuels[BEV_S4_2027,2027,Electricity,D1] = 2.0
# vehicle_list_fuels[BEV_S4_2027,2027,Electricity,D2] = 16.0
# vehicle_list_fuels[BEV_S4_2027,2028,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2028,Electricity,D2] = 12.0
# vehicle_list_fuels[BEV_S4_2027,2029,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2029,Electricity,D2] = 16.0
# vehicle_list_fuels[BEV_S4_2027,2030,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2030,Electricity,D2] = 16.0
# vehicle_list_fuels[BEV_S4_2027,2031,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2031,Electricity,D2] = 16.0
# vehicle_list_fuels[BEV_S4_2027,2032,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2032,Electricity,D2] = 18.0
# vehicle_list_fuels[BEV_S4_2027,2033,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2033,Electricity,D2] = 18.0
# vehicle_list_fuels[BEV_S4_2027,2034,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2034,Electricity,D2] = 18.0
# vehicle_list_fuels[BEV_S4_2027,2035,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2035,Electricity,D2] = 19.0
# vehicle_list_fuels[BEV_S4_2027,2036,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2027,2036,Electricity,D2] = 20.0
# vehicle_list_fuels[BEV_S4_2028,2028,Electricity,D2] = 4.0
# vehicle_list_fuels[BEV_S4_2028,2037,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2028,2037,Electricity,D2] = 20.0
# vehicle_list_fuels[BEV_S4_2029,2029,Electricity,D3] = 2.0
# vehicle_list_fuels[BEV_S4_2029,2030,Electricity,D3] = 2.0
# vehicle_list_fuels[BEV_S4_2029,2031,Electricity,D3] = 2.0
# vehicle_list_fuels[BEV_S4_2029,2032,Electricity,D3] = 2.0
# vehicle_list_fuels[BEV_S4_2029,2033,Electricity,D3] = 2.0
# vehicle_list_fuels[BEV_S4_2029,2034,Electricity,D3] = 2.0
# vehicle_list_fuels[BEV_S4_2029,2035,Electricity,D3] = 3.0
# vehicle_list_fuels[BEV_S4_2029,2036,Electricity,D3] = 2.0
# vehicle_list_fuels[BEV_S4_2029,2037,Electricity,D3] = 3.0
# vehicle_list_fuels[BEV_S4_2029,2038,Electricity,D1] = 1.0
# vehicle_list_fuels[BEV_S4_2029,2038,Electricity,D2] = 29.0
# vehicle_list_fuels[BEV_S4_2029,2038,Electricity,D3] = 3.0
# vehicle_list_fuels[BEV_S4_2032,2032,Electricity,D4] = 1.0
# vehicle_list_fuels[BEV_S4_2032,2036,Electricity,D4] = 1.0
# vehicle_list_fuels[BEV_S4_2033,2033,Electricity,D4] = 1.0
# vehicle_list_fuels[BEV_S4_2033,2037,Electricity,D4] = 1.0
# vehicle_list_fuels[BEV_S4_2034,2034,Electricity,D4] = 1.0
# vehicle_list_fuels[BEV_S4_2035,2035,Electricity,D4] = 1.0
# vehicle_list_fuels[BEV_S4_2036,2038,Electricity,D4] = 1.0
# vehicle_list_fuels[BEV_S3_2023,2024,Electricity,D1] = 23.0
# vehicle_list_fuels[BEV_S3_2023,2025,Electricity,D1] = 13.0
# vehicle_list_fuels[BEV_S3_2023,2026,Electricity,D1] = 64.0
# vehicle_list_fuels[BEV_S3_2024,2024,Electricity,D1] = 16.0
# vehicle_list_fuels[BEV_S3_2024,2025,Electricity,D1] = 13.0
# vehicle_list_fuels[BEV_S3_2025,2025,Electricity,D1] = 5.0
# vehicle_list_fuels[BEV_S3_2026,2026,Electricity,D2] = 70.0
# vehicle_list_fuels[BEV_S3_2027,2027,Electricity,D1] = 66.0
# vehicle_list_fuels[BEV_S3_2027,2027,Electricity,D2] = 72.0
# vehicle_list_fuels[BEV_S3_2027,2028,Electricity,D1] = 68.0
# vehicle_list_fuels[BEV_S3_2027,2028,Electricity,D2] = 74.0
# vehicle_list_fuels[BEV_S3_2027,2029,Electricity,D1] = 101.0
# vehicle_list_fuels[BEV_S3_2027,2029,Electricity,D2] = 101.0
# vehicle_list_fuels[BEV_S3_2027,2030,Electricity,D1] = 34.0
# vehicle_list_fuels[BEV_S3_2027,2030,Electricity,D2] = 77.0
# vehicle_list_fuels[BEV_S3_2027,2031,Electricity,D1] = 72.0
# vehicle_list_fuels[BEV_S3_2027,2031,Electricity,D2] = 78.0
# vehicle_list_fuels[BEV_S3_2027,2032,Electricity,D1] = 76.0
# vehicle_list_fuels[BEV_S3_2027,2032,Electricity,D2] = 80.0
# vehicle_list_fuels[BEV_S3_2027,2033,Electricity,D1] = 78.0
# vehicle_list_fuels[BEV_S3_2027,2033,Electricity,D2] = 82.0
# vehicle_list_fuels[BEV_S3_2027,2034,Electricity,D1] = 78.0
# vehicle_list_fuels[BEV_S3_2027,2034,Electricity,D2] = 86.0
# vehicle_list_fuels[BEV_S3_2027,2035,Electricity,D1] = 80.0
# vehicle_list_fuels[BEV_S3_2027,2035,Electricity,D2] = 89.0
# vehicle_list_fuels[BEV_S3_2027,2036,Electricity,D1] = 82.0
# vehicle_list_fuels[BEV_S3_2027,2036,Electricity,D2] = 90.0
# vehicle_list_fuels[BEV_S3_2028,2029,Electricity,D1] = 117.0
# vehicle_list_fuels[BEV_S3_2028,2029,Electricity,D2] = 162.0
# vehicle_list_fuels[BEV_S3_2028,2030,Electricity,D1] = 35.0
# vehicle_list_fuels[BEV_S3_2028,2037,Electricity,D1] = 86.0
# vehicle_list_fuels[BEV_S3_2028,2037,Electricity,D2] = 90.0
# vehicle_list_fuels[BEV_S3_2029,2029,Electricity,D3] = 17.0
# vehicle_list_fuels[BEV_S3_2029,2030,Electricity,D3] = 17.0
# vehicle_list_fuels[BEV_S3_2029,2031,Electricity,D3] = 17.0
# vehicle_list_fuels[BEV_S3_2029,2032,Electricity,D3] = 36.0
# vehicle_list_fuels[BEV_S3_2029,2033,Electricity,D3] = 18.0
# vehicle_list_fuels[BEV_S3_2029,2034,Electricity,D3] = 19.0
# vehicle_list_fuels[BEV_S3_2029,2035,Electricity,D3] = 19.0
# vehicle_list_fuels[BEV_S3_2029,2036,Electricity,D3] = 19.0
# vehicle_list_fuels[BEV_S3_2029,2037,Electricity,D3] = 19.0
# vehicle_list_fuels[BEV_S3_2029,2038,Electricity,D1] = 89.0
# vehicle_list_fuels[BEV_S3_2029,2038,Electricity,D2] = 91.0
# vehicle_list_fuels[BEV_S3_2029,2038,Electricity,D3] = 3028.0
# vehicle_list_fuels[BEV_S3_2032,2032,Electricity,D4] = 4.0
# vehicle_list_fuels[BEV_S3_2032,2033,Electricity,D4] = 4.0
# vehicle_list_fuels[BEV_S3_2032,2034,Electricity,D4] = 8.0
# vehicle_list_fuels[BEV_S3_2032,2035,Electricity,D4] = 4.0
# vehicle_list_fuels[BEV_S3_2032,2036,Electricity,D4] = 8.0
# vehicle_list_fuels[BEV_S3_2032,2037,Electricity,D4] = 5.0
# vehicle_list_fuels[BEV_S3_2032,2038,Electricity,D4] = 5.0
# vehicle_list_fuels[LNG_S1_2023,2023,LNG,D1] = 222.0
# vehicle_list_fuels[LNG_S1_2023,2023,LNG,D2] = 94.0
# vehicle_list_fuels[LNG_S1_2023,2023,LNG,D3] = 49.0
# vehicle_list_fuels[LNG_S1_2023,2023,LNG,D4] = 217.0
# vehicle_list_fuels[LNG_S1_2023,2024,LNG,D2] = 302.0
# vehicle_list_fuels[LNG_S1_2023,2024,LNG,D3] = 371.0
# vehicle_list_fuels[LNG_S1_2023,2024,LNG,D4] = 5.0
# vehicle_list_fuels[LNG_S1_2023,2025,LNG,D2] = 72.0
# vehicle_list_fuels[LNG_S1_2023,2025,LNG,D3] = 22289.0
# vehicle_list_fuels[LNG_S1_2023,2025,LNG,D4] = 5.0
# vehicle_list_fuels[LNG_S1_2024,2025,LNG,D2] = 9.0
# vehicle_list_fuels[LNG_S1_2025,2025,LNG,D2] = 9.0
# vehicle_list_fuels[LNG_S1_2026,2026,LNG,D3] = 70.0
# vehicle_list_fuels[LNG_S1_2026,2026,LNG,D4] = 10.0
# vehicle_list_fuels[LNG_S1_2027,2027,LNG,D3] = 72.0
# vehicle_list_fuels[LNG_S1_2027,2027,LNG,D4] = 10.0
# vehicle_list_fuels[LNG_S1_2028,2028,LNG,D3] = 74.0
# vehicle_list_fuels[LNG_S1_2028,2028,LNG,D4] = 10.0
# vehicle_list_fuels[LNG_S1_2029,2029,LNG,D4] = 5.0
# vehicle_list_fuels[LNG_S1_2029,2030,LNG,D4] = 5.0
# vehicle_list_fuels[LNG_S1_2029,2031,LNG,D4] = 6.0
# vehicle_list_fuels[LNG_S2_2023,2023,LNG,D1] = 13.0
# vehicle_list_fuels[LNG_S2_2023,2023,LNG,D2] = 160.0
# vehicle_list_fuels[LNG_S2_2023,2023,LNG,D3] = 467.0
# vehicle_list_fuels[LNG_S2_2023,2023,LNG,D4] = 7.0
# vehicle_list_fuels[LNG_S2_2023,2024,LNG,D2] = 14.0
# vehicle_list_fuels[LNG_S2_2023,2024,LNG,D3] = 8.0
# vehicle_list_fuels[LNG_S2_2023,2024,LNG,D4] = 2.0
# vehicle_list_fuels[LNG_S2_2023,2025,LNG,D2] = 218.0
# vehicle_list_fuels[LNG_S2_2023,2025,LNG,D3] = 8.0
# vehicle_list_fuels[LNG_S2_2023,2025,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S2_2024,2024,LNG,D3] = 16.0
# vehicle_list_fuels[LNG_S2_2024,2024,LNG,D4] = 4.0
# vehicle_list_fuels[LNG_S2_2024,2025,LNG,D2] = 9.0
# vehicle_list_fuels[LNG_S2_2024,2025,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S2_2025,2025,LNG,D2] = 4.0
# vehicle_list_fuels[LNG_S2_2025,2025,LNG,D3] = 3.0
# vehicle_list_fuels[LNG_S2_2026,2026,LNG,D3] = 16.0
# vehicle_list_fuels[LNG_S2_2026,2026,LNG,D4] = 4.0
# vehicle_list_fuels[LNG_S2_2027,2027,LNG,D3] = 18.0
# vehicle_list_fuels[LNG_S2_2027,2027,LNG,D4] = 4.0
# vehicle_list_fuels[LNG_S2_2028,2028,LNG,D3] = 18.0
# vehicle_list_fuels[LNG_S2_2028,2028,LNG,D4] = 4.0
# vehicle_list_fuels[LNG_S2_2029,2029,LNG,D4] = 2.0
# vehicle_list_fuels[LNG_S2_2029,2030,LNG,D4] = 2.0
# vehicle_list_fuels[LNG_S2_2029,2031,LNG,D4] = 4.0
# vehicle_list_fuels[LNG_S4_2023,2023,LNG,D1] = 1.0
# vehicle_list_fuels[LNG_S4_2023,2023,LNG,D2] = 11.0
# vehicle_list_fuels[LNG_S4_2023,2023,LNG,D3] = 4.0
# vehicle_list_fuels[LNG_S4_2023,2023,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S4_2023,2024,LNG,D2] = 7.0
# vehicle_list_fuels[LNG_S4_2023,2024,LNG,D3] = 2.0
# vehicle_list_fuels[LNG_S4_2023,2024,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S4_2023,2025,LNG,D3] = 1.0
# vehicle_list_fuels[LNG_S4_2023,2025,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S4_2024,2024,LNG,D3] = 2.0
# vehicle_list_fuels[LNG_S4_2024,2025,LNG,D2] = 6.0
# vehicle_list_fuels[LNG_S4_2025,2025,LNG,D2] = 3.0
# vehicle_list_fuels[LNG_S4_2025,2025,LNG,D3] = 1.0
# vehicle_list_fuels[LNG_S4_2026,2026,LNG,D3] = 4.0
# vehicle_list_fuels[LNG_S4_2026,2026,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S4_2027,2027,LNG,D3] = 4.0
# vehicle_list_fuels[LNG_S4_2027,2027,LNG,D4] = 2.0
# vehicle_list_fuels[LNG_S4_2028,2028,LNG,D3] = 4.0
# vehicle_list_fuels[LNG_S4_2028,2028,LNG,D4] = 2.0
# vehicle_list_fuels[LNG_S4_2029,2029,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S4_2029,2030,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S4_2031,2031,LNG,D4] = 1.0
# vehicle_list_fuels[LNG_S3_2023,2023,LNG,D1] = 3116.0
# vehicle_list_fuels[LNG_S3_2023,2023,LNG,D2] = 636.0
# vehicle_list_fuels[LNG_S3_2023,2023,LNG,D3] = 5198076.0
# vehicle_list_fuels[LNG_S3_2023,2023,LNG,D4] = 3.0
# vehicle_list_fuels[LNG_S3_2023,2024,LNG,D2] = 561.0
# vehicle_list_fuels[LNG_S3_2023,2024,LNG,D3] = 15.0
# vehicle_list_fuels[LNG_S3_2023,2024,LNG,D4] = 3.0
# vehicle_list_fuels[LNG_S3_2023,2025,LNG,D2] = 27.0
# vehicle_list_fuels[LNG_S3_2023,2025,LNG,D3] = 13.0
# vehicle_list_fuels[LNG_S3_2024,2024,LNG,D4] = 3.0
# vehicle_list_fuels[LNG_S3_2024,2025,LNG,D2] = 13.0
# vehicle_list_fuels[LNG_S3_2024,2025,LNG,D3] = 1.0
# vehicle_list_fuels[LNG_S3_2024,2025,LNG,D4] = 3.0
# vehicle_list_fuels[LNG_S3_2025,2025,LNG,D2] = 8.0
# vehicle_list_fuels[LNG_S3_2025,2025,LNG,D3] = 296.0
# vehicle_list_fuels[LNG_S3_2026,2026,LNG,D3] = 32.0
# vehicle_list_fuels[LNG_S3_2026,2026,LNG,D4] = 7.0
# vehicle_list_fuels[LNG_S3_2027,2027,LNG,D3] = 32.0
# vehicle_list_fuels[LNG_S3_2027,2027,LNG,D4] = 8.0
# vehicle_list_fuels[LNG_S3_2028,2028,LNG,D3] = 32.0
# vehicle_list_fuels[LNG_S3_2028,2028,LNG,D4] = 8.0
# vehicle_list_fuels[LNG_S3_2029,2029,LNG,D4] = 4.0
# vehicle_list_fuels[LNG_S3_2029,2030,LNG,D4] = 4.0
# vehicle_list_fuels[LNG_S3_2029,2031,LNG,D4] = 4.0
# distance[BEV_S1_2023,2024,Electricity,D1] = 97471.33333333333
# distance[BEV_S1_2023,2025,Electricity,D1] = 97523.0
# distance[BEV_S1_2023,2026,Electricity,D1] = 49116.38888888889
# distance[BEV_S1_2026,2026,Electricity,D2] = 50157.75862068965
# distance[BEV_S1_2027,2027,Electricity,D1] = 46150.2
# distance[BEV_S1_2027,2027,Electricity,D2] = 50385.88333333333
# distance[BEV_S1_2027,2028,Electricity,D1] = 48406.85
# distance[BEV_S1_2027,2028,Electricity,D2] = 50228.306451612894
# distance[BEV_S1_2027,2029,Electricity,D1] = 100962.9
# distance[BEV_S1_2027,2030,Electricity,D1] = 50489.89999996126
# distance[BEV_S1_2027,2030,Electricity,D2] = 51510.100000051214
# distance[BEV_S1_2027,2031,Electricity,D1] = 1675.2121212266507
# distance[BEV_S1_2027,2031,Electricity,D2] = 100324.78787877341
# distance[BEV_S1_2027,2032,Electricity,D1] = 1089.3482688384058
# distance[BEV_S1_2027,2032,Electricity,D2] = 100909.82352941176
# distance[BEV_S1_2027,2033,Electricity,D1] = 97355.90909087965
# distance[BEV_S1_2027,2034,Electricity,D1] = 98199.81818181819
# distance[BEV_S1_2027,2035,Electricity,D1] = 100610.81818175314
# distance[BEV_S1_2027,2036,Electricity,D1] = 1436.8115577889448
# distance[BEV_S1_2027,2036,Electricity,D2] = 100562.97368421052
# distance[BEV_S1_2028,2031,Electricity,D1] = 100539.63333330138
# distance[BEV_S1_2028,2033,Electricity,D2] = 99768.17142857143
# distance[BEV_S1_2028,2037,Electricity,D2] = 101360.30769230769
# distance[BEV_S1_2029,2029,Electricity,D2] = 2197.345968297726
# distance[BEV_S1_2029,2029,Electricity,D3] = 99802.51282050755
# distance[BEV_S1_2029,2030,Electricity,D2] = 49711.366666169924
# distance[BEV_S1_2029,2030,Electricity,D3] = 51591.163636363635
# distance[BEV_S1_2029,2031,Electricity,D3] = 50768.112499994044
# distance[BEV_S1_2029,2032,Electricity,D3] = 50440.78571428572
# distance[BEV_S1_2029,2033,Electricity,D3] = 99769.37209302325
# distance[BEV_S1_2029,2034,Electricity,D3] = 101699.15909090909
# distance[BEV_S1_2029,2035,Electricity,D2] = 50623.594594583315
# distance[BEV_S1_2029,2035,Electricity,D3] = 50868.71590909091
# distance[BEV_S1_2029,2036,Electricity,D3] = 99982.97826086957
# distance[BEV_S1_2029,2037,Electricity,D3] = 101390.5652173913
# distance[BEV_S1_2029,2038,Electricity,D1] = 2144.201709401709
# distance[BEV_S1_2029,2038,Electricity,D2] = 99854.225
# distance[BEV_S1_2030,2030,Electricity,D3] = 102000.0
# distance[BEV_S1_2030,2038,Electricity,D3] = 50498.65624999503
# distance[BEV_S1_2031,2037,Electricity,D1] = 99688.75
# distance[BEV_S1_2032,2032,Electricity,D4] = 45243.416666651145
# distance[BEV_S1_2032,2033,Electricity,D4] = 46942.74999995033
# distance[BEV_S1_2032,2034,Electricity,D2] = 53833.432835820895
# distance[BEV_S1_2032,2034,Electricity,D4] = 47953.74999995778
# distance[BEV_S1_2032,2035,Electricity,D4] = 2649.5315315279067
# distance[BEV_S1_2032,2036,Electricity,D4] = 50213.083333301045
# distance[BEV_S1_2032,2037,Electricity,D4] = 45006.57142852883
# distance[BEV_S1_2032,2038,Electricity,D4] = 91745.14285714286
# distance[BEV_S2_2023,2024,Electricity,D1] = 104320.9
# distance[BEV_S2_2023,2025,Electricity,D1] = 106000.0
# distance[BEV_S2_2023,2026,Electricity,D1] = 49577.40909090908
# distance[BEV_S2_2024,2025,Electricity,D1] = 106000.0
# distance[BEV_S2_2025,2025,Electricity,D1] = 22065.0
# distance[BEV_S2_2026,2026,Electricity,D2] = 51881.53571428572
# distance[BEV_S2_2027,2027,Electricity,D1] = 50679.86363636364
# distance[BEV_S2_2027,2027,Electricity,D2] = 52859.892857142855
# distance[BEV_S2_2027,2028,Electricity,D1] = 51917.181818181816
# distance[BEV_S2_2027,2028,Electricity,D2] = 51556.76666666667
# distance[BEV_S2_2027,2029,Electricity,D1] = 97801.33333333333
# distance[BEV_S2_2027,2029,Electricity,D2] = 8178.010752687531
# distance[BEV_S2_2027,2030,Electricity,D1] = 41043.1
# distance[BEV_S2_2027,2030,Electricity,D2] = 50757.43749999038
# distance[BEV_S2_2027,2031,Electricity,D1] = 51683.41666664431
# distance[BEV_S2_2027,2031,Electricity,D2] = 52787.37499997765
# distance[BEV_S2_2027,2032,Electricity,D1] = 2497.4705882335616
# distance[BEV_S2_2027,2032,Electricity,D2] = 103483.23529411765
# distance[BEV_S2_2027,2033,Electricity,D1] = 687.4117647250388
# distance[BEV_S2_2027,2033,Electricity,D2] = 105312.58823527505
# distance[BEV_S2_2027,2034,Electricity,D1] = 2142.50000004645
# distance[BEV_S2_2027,2034,Electricity,D2] = 103857.49999995361
# distance[BEV_S2_2027,2035,Electricity,D1] = 4168.311728395061
# distance[BEV_S2_2027,2035,Electricity,D2] = 101822.15789473684
# distance[BEV_S2_2027,2036,Electricity,D1] = 49597.46428571428
# distance[BEV_S2_2027,2036,Electricity,D2] = 56201.36842097023
# distance[BEV_S2_2028,2029,Electricity,D2] = 106000.0
# distance[BEV_S2_2028,2037,Electricity,D1] = 2043.776967928639
# distance[BEV_S2_2028,2037,Electricity,D2] = 103955.24999996243
# distance[BEV_S2_2029,2029,Electricity,D3] = 101846.33333333333
# distance[BEV_S2_2029,2030,Electricity,D3] = 103497.55555555556
# distance[BEV_S2_2029,2031,Electricity,D3] = 52415.111111074686
# distance[BEV_S2_2029,2032,Electricity,D3] = 98042.99999996422
# distance[BEV_S2_2029,2033,Electricity,D1] = 55006.66496161517
# distance[BEV_S2_2029,2033,Electricity,D3] = 50362.94999995232
# distance[BEV_S2_2029,2034,Electricity,D3] = 104393.59999996424
# distance[BEV_S2_2029,2035,Electricity,D3] = 52693.5
# distance[BEV_S2_2029,2036,Electricity,D3] = 100290.63636356863
# distance[BEV_S2_2029,2037,Electricity,D3] = 51446.909090909096
# distance[BEV_S2_2029,2038,Electricity,D1] = 50381.892857142855
# distance[BEV_S2_2029,2038,Electricity,D2] = 6113.079545454546
# distance[BEV_S2_2029,2038,Electricity,D3] = 49497.416666666664
# distance[BEV_S2_2030,2034,Electricity,D1] = 99160.76923067633
# distance[BEV_S2_2032,2032,Electricity,D1] = 24437.0
# distance[BEV_S2_2032,2032,Electricity,D4] = 81563.0
# distance[BEV_S2_2032,2033,Electricity,D4] = 84070.5
# distance[BEV_S2_2032,2034,Electricity,D4] = 42367.99999991059
# distance[BEV_S2_2032,2035,Electricity,D4] = 88464.5
# distance[BEV_S2_2032,2036,Electricity,D2] = 60965.00000010438
# distance[BEV_S2_2032,2036,Electricity,D4] = 45034.99999989569
# distance[BEV_S2_2032,2037,Electricity,D4] = 31122.166666537523
# distance[BEV_S2_2032,2038,Electricity,D4] = 95444.49999982119
# distance[BEV_S4_2023,2024,Electricity,D1] = 15200.0
# distance[BEV_S4_2023,2025,Electricity,D1] = 15614.999999575317
# distance[BEV_S4_2023,2026,Electricity,D1] = 15916.0
# distance[BEV_S4_2026,2026,Electricity,D2] = 56745.0
# distance[BEV_S4_2027,2027,Electricity,D1] = 8266.0
# distance[BEV_S4_2027,2027,Electricity,D2] = 51834.187499999985
# distance[BEV_S4_2027,2028,Electricity,D1] = 16863.0
# distance[BEV_S4_2027,2028,Electricity,D2] = 70996.08333333333
# distance[BEV_S4_2027,2029,Electricity,D1] = 17544.0
# distance[BEV_S4_2027,2029,Electricity,D2] = 55366.4375
# distance[BEV_S4_2027,2030,Electricity,D1] = 18167.99999971318
# distance[BEV_S4_2027,2030,Electricity,D2] = 57455.6249999702
# distance[BEV_S4_2027,2031,Electricity,D1] = 18747.0
# distance[BEV_S4_2027,2031,Electricity,D2] = 58872.49999997765
# distance[BEV_S4_2027,2032,Electricity,D1] = 19297.999999910593
# distance[BEV_S4_2027,2032,Electricity,D2] = 53747.83333330707
# distance[BEV_S4_2027,2033,Electricity,D1] = 19951.0
# distance[BEV_S4_2027,2033,Electricity,D2] = 56287.44444439146
# distance[BEV_S4_2027,2034,Electricity,D1] = 20807.0
# distance[BEV_S4_2027,2034,Electricity,D2] = 58729.611111091246
# distance[BEV_S4_2027,2035,Electricity,D1] = 21666.0
# distance[BEV_S4_2027,2035,Electricity,D2] = 58304.57894731823
# distance[BEV_S4_2027,2036,Electricity,D1] = 22740.0
# distance[BEV_S4_2027,2036,Electricity,D2] = 56711.89999998212
# distance[BEV_S4_2028,2037,Electricity,D1] = 23253.999999046326
# distance[BEV_S4_2028,2037,Electricity,D2] = 57325.99999998808
# distance[BEV_S4_2029,2029,Electricity,D3] = 67901.5
# distance[BEV_S4_2029,2030,Electricity,D3] = 68172.0
# distance[BEV_S4_2029,2031,Electricity,D3] = 69848.0
# distance[BEV_S4_2029,2032,Electricity,D3] = 70695.49999982119
# distance[BEV_S4_2029,2033,Electricity,D3] = 73134.99999986589
# distance[BEV_S4_2029,2034,Electricity,D3] = 73166.5
# distance[BEV_S4_2029,2035,Electricity,D3] = 49196.66666646798
# distance[BEV_S4_2029,2036,Electricity,D3] = 75545.0
# distance[BEV_S4_2029,2037,Electricity,D3] = 52172.666666408375
# distance[BEV_S4_2029,2038,Electricity,D1] = 23437.0
# distance[BEV_S4_2029,2038,Electricity,D2] = 39605.3448275862
# distance[BEV_S4_2029,2038,Electricity,D3] = 53795.333333333336
# distance[BEV_S4_2032,2032,Electricity,D4] = 2230.0
# distance[BEV_S4_2032,2036,Electricity,D4] = 2412.0
# distance[BEV_S4_2033,2033,Electricity,D4] = 2235.9999997479026
# distance[BEV_S4_2033,2037,Electricity,D4] = 2413.999999626336
# distance[BEV_S4_2034,2034,Electricity,D4] = 2279.9999997245613
# distance[BEV_S4_2035,2035,Electricity,D4] = 2368.999999741107
# distance[BEV_S4_2036,2038,Electricity,D4] = 2445.999999940803
# distance[BEV_S3_2023,2024,Electricity,D1] = 73000.0
# distance[BEV_S3_2023,2025,Electricity,D1] = 73000.0
# distance[BEV_S3_2023,2026,Electricity,D1] = 36402.703125
# distance[BEV_S3_2024,2024,Electricity,D1] = 35027.5
# distance[BEV_S3_2024,2025,Electricity,D1] = 72395.07692307692
# distance[BEV_S3_2025,2025,Electricity,D1] = 73000.0
# distance[BEV_S3_2026,2026,Electricity,D2] = 36069.9
# distance[BEV_S3_2027,2027,Electricity,D1] = 36081.34848484849
# distance[BEV_S3_2027,2027,Electricity,D2] = 35993.97222222222
# distance[BEV_S3_2027,2028,Electricity,D1] = 36006.94117647059
# distance[BEV_S3_2027,2028,Electricity,D2] = 36053.02702702703
# distance[BEV_S3_2027,2029,Electricity,D1] = 13837.168316831683
# distance[BEV_S3_2027,2029,Electricity,D2] = 13837.168316831683
# distance[BEV_S3_2027,2030,Electricity,D2] = 36370.1038961039
# distance[BEV_S3_2027,2031,Electricity,D1] = 36377.27777776453
# distance[BEV_S3_2027,2031,Electricity,D2] = 36079.02564102564
# distance[BEV_S3_2027,2032,Electricity,D1] = 35633.328947357426
# distance[BEV_S3_2027,2032,Electricity,D2] = 35795.925
# distance[BEV_S3_2027,2033,Electricity,D1] = 36166.55128205128
# distance[BEV_S3_2027,2033,Electricity,D2] = 36270.365853658535
# distance[BEV_S3_2027,2034,Electricity,D1] = 36309.653846153844
# distance[BEV_S3_2027,2034,Electricity,D2] = 36009.76744184936
# distance[BEV_S3_2027,2035,Electricity,D1] = 36356.7875
# distance[BEV_S3_2027,2035,Electricity,D2] = 36487.651685393255
# distance[BEV_S3_2027,2036,Electricity,D1] = 36382.329268292684
# distance[BEV_S3_2027,2036,Electricity,D2] = 36331.91111111111
# distance[BEV_S3_2028,2029,Electricity,D1] = 9398.28205128205
# distance[BEV_S3_2028,2029,Electricity,D2] = 8626.876543209877
# distance[BEV_S3_2028,2030,Electricity,D1] = 71948.22857142857
# distance[BEV_S3_2028,2037,Electricity,D1] = 36381.62790697674
# distance[BEV_S3_2028,2037,Electricity,D2] = 36388.78888888889
# distance[BEV_S3_2029,2029,Electricity,D3] = 69148.70588235294
# distance[BEV_S3_2029,2030,Electricity,D3] = 71562.88235294117
# distance[BEV_S3_2029,2031,Electricity,D3] = 72596.94117647059
# distance[BEV_S3_2029,2032,Electricity,D3] = 34840.58333332173
# distance[BEV_S3_2029,2033,Electricity,D3] = 70563.27777775789
# distance[BEV_S3_2029,2034,Electricity,D3] = 69514.1052631579
# distance[BEV_S3_2029,2035,Electricity,D3] = 71596.68421047521
# distance[BEV_S3_2029,2036,Electricity,D3] = 72490.84210524432
# distance[BEV_S3_2029,2037,Electricity,D3] = 72894.10526312023
# distance[BEV_S3_2029,2038,Electricity,D1] = 36284.02247191011
# distance[BEV_S3_2029,2038,Electricity,D2] = 36237.560439560446
# distance[BEV_S3_2029,2038,Electricity,D3] = 478.385072655218
# distance[BEV_S3_2032,2032,Electricity,D4] = 62619.75
# distance[BEV_S3_2032,2033,Electricity,D4] = 65578.25
# distance[BEV_S3_2032,2034,Electricity,D4] = 34131.624999947846
# distance[BEV_S3_2032,2035,Electricity,D4] = 68685.25
# distance[BEV_S3_2032,2036,Electricity,D4] = 35114.2499999553
# distance[BEV_S3_2032,2037,Electricity,D4] = 58571.19999991631
# distance[BEV_S3_2032,2038,Electricity,D4] = 61382.0
# distance[LNG_S1_2023,2023,LNG,D1] = 3915.2297297296836
# distance[LNG_S1_2023,2023,LNG,D2] = 27628.65957446798
# distance[LNG_S1_2023,2023,LNG,D3] = 67183.89795918348
# distance[LNG_S1_2023,2023,LNG,D4] = 1909.2857142857142
# distance[LNG_S1_2023,2024,LNG,D2] = 8994.023178807947
# distance[LNG_S1_2023,2024,LNG,D3] = 8993.541778975741
# distance[LNG_S1_2023,2024,LNG,D4] = 83996.2
# distance[LNG_S1_2023,2025,LNG,D2] = 13891.98951952031
# distance[LNG_S1_2023,2025,LNG,D3] = 154.61048050607113
# distance[LNG_S1_2023,2025,LNG,D4] = 87953.4
# distance[LNG_S1_2024,2025,LNG,D2] = 102000.0
# distance[LNG_S1_2025,2025,LNG,D2] = 101999.9727327264
# distance[LNG_S1_2026,2026,LNG,D3] = 50529.0
# distance[LNG_S1_2026,2026,LNG,D4] = 44647.8
# distance[LNG_S1_2027,2027,LNG,D3] = 49745.569444444445
# distance[LNG_S1_2027,2027,LNG,D4] = 46717.4
# distance[LNG_S1_2028,2028,LNG,D3] = 50422.55405405405
# distance[LNG_S1_2028,2028,LNG,D4] = 46916.8
# distance[LNG_S1_2029,2029,LNG,D4] = 96934.2
# distance[LNG_S1_2029,2030,LNG,D4] = 99254.6
# distance[LNG_S1_2029,2031,LNG,D4] = 86441.83333333333
# distance[LNG_S2_2023,2023,LNG,D1] = 76591.84615384544
# distance[LNG_S2_2023,2023,LNG,D2] = 8644.974999999948
# distance[LNG_S2_2023,2023,LNG,D3] = 1665.9700214132583
# distance[LNG_S2_2023,2023,LNG,D4] = 19096.714285714286
# distance[LNG_S2_2023,2024,LNG,D2] = 99427.64285714286
# distance[LNG_S2_2023,2024,LNG,D3] = 6572.357142857143
# distance[LNG_S2_2023,2025,LNG,D2] = 6195.909967845662
# distance[LNG_S2_2023,2025,LNG,D3] = 68573.09003215434
# distance[LNG_S2_2023,2025,LNG,D4] = 31231.0
# distance[LNG_S2_2024,2024,LNG,D3] = 47156.07142857143
# distance[LNG_S2_2024,2024,LNG,D4] = 33428.0
# distance[LNG_S2_2024,2025,LNG,D4] = 106000.0
# distance[LNG_S2_2025,2025,LNG,D2] = 14968.906752411567
# distance[LNG_S2_2025,2025,LNG,D3] = 91031.09324758843
# distance[LNG_S2_2026,2026,LNG,D3] = 51621.1875
# distance[LNG_S2_2026,2026,LNG,D4] = 35282.0
# distance[LNG_S2_2027,2027,LNG,D3] = 47936.166666666664
# distance[LNG_S2_2027,2027,LNG,D4] = 36612.0
# distance[LNG_S2_2028,2028,LNG,D3] = 50134.166666666664
# distance[LNG_S2_2028,2028,LNG,D4] = 37009.0
# distance[LNG_S2_2029,2029,LNG,D4] = 74161.0
# distance[LNG_S2_2029,2030,LNG,D4] = 77782.5
# distance[LNG_S2_2029,2031,LNG,D4] = 40494.249999988824
# distance[LNG_S4_2023,2023,LNG,D1] = 14576.0
# distance[LNG_S4_2023,2023,LNG,D2] = 68610.63636363555
# distance[LNG_S4_2023,2023,LNG,D3] = 29724.75
# distance[LNG_S4_2023,2023,LNG,D4] = 1809.0
# distance[LNG_S4_2023,2024,LNG,D2] = 111568.42857142857
# distance[LNG_S4_2023,2024,LNG,D3] = 4538.571428571428
# distance[LNG_S4_2023,2024,LNG,D4] = 1893.0
# distance[LNG_S4_2023,2025,LNG,D3] = 116073.00000026831
# distance[LNG_S4_2023,2025,LNG,D4] = 1926.999999731779
# distance[LNG_S4_2024,2024,LNG,D3] = 56554.42857142857
# distance[LNG_S4_2024,2025,LNG,D2] = 118000.0
# distance[LNG_S4_2025,2025,LNG,D2] = 27693.0
# distance[LNG_S4_2025,2025,LNG,D3] = 7178.999999731692
# distance[LNG_S4_2026,2026,LNG,D3] = 31678.75
# distance[LNG_S4_2026,2026,LNG,D4] = 1989.0
# distance[LNG_S4_2027,2027,LNG,D3] = 32441.25
# distance[LNG_S4_2027,2027,LNG,D4] = 1009.5
# distance[LNG_S4_2028,2028,LNG,D3] = 33482.25
# distance[LNG_S4_2028,2028,LNG,D4] = 1033.0
# distance[LNG_S4_2029,2029,LNG,D4] = 2113.0
# distance[LNG_S4_2029,2030,LNG,D4] = 2113.9999991654768
# distance[LNG_S4_2031,2031,LNG,D4] = 2198.0
# distance[LNG_S3_2023,2023,LNG,D1] = 700.7301026957633
# distance[LNG_S3_2023,2023,LNG,D2] = 3823.743710691808
# distance[LNG_S3_2023,2023,LNG,D3] = 0.1928532787900738
# distance[LNG_S3_2023,2023,LNG,D4] = 68475.33333333333
# distance[LNG_S3_2023,2024,LNG,D2] = 4373.434937611408
# distance[LNG_S3_2023,2024,LNG,D3] = 68625.0
# distance[LNG_S3_2023,2024,LNG,D4] = 1.565062388592196
# distance[LNG_S3_2023,2025,LNG,D2] = 71975.48343469264
# distance[LNG_S3_2023,2025,LNG,D3] = 1024.516565307366
# distance[LNG_S3_2024,2024,LNG,D4] = 69478.43493761141
# distance[LNG_S3_2024,2025,LNG,D2] = 154.33333345751453
# distance[LNG_S3_2024,2025,LNG,D4] = 72845.66666654249
# distance[LNG_S3_2025,2025,LNG,D2] = 69485.3267410439
# distance[LNG_S3_2025,2025,LNG,D3] = 3514.673258956095
# distance[LNG_S3_2026,2026,LNG,D3] = 34497.71875
# distance[LNG_S3_2026,2026,LNG,D4] = 31311.571428571428
# distance[LNG_S3_2027,2027,LNG,D3] = 35546.6875
# distance[LNG_S3_2027,2027,LNG,D4] = 28117.125
# distance[LNG_S3_2028,2028,LNG,D3] = 36104.03125
# distance[LNG_S3_2028,2028,LNG,D4] = 29182.75
# distance[LNG_S3_2029,2029,LNG,D4] = 58538.75
# distance[LNG_S3_2029,2030,LNG,D4] = 60191.75
# distance[LNG_S3_2029,2031,LNG,D4] = 60703.2499999824

# %%
m.computeIIS()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12700, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 20 logical processors, using up to 20 threads
#
# IIS computation: initial model status unknown, solving to determine model status
# Presolve removed 370364 rows and 86552 columns
# Presolve time: 0.08s
# Presolved: 30852 rows, 47625 columns, 77792 nonzeros
# Presolved model has 4960 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
#
# Solving non-convex MIQCP
#
# Variable types: 25441 continuous, 22184 integer (0 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.23 seconds (0.17 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# Computing Irreducible Inconsistent Subsystem (IIS)...
#
#            Constraints          |            Bounds           |  Runtime
#       Min       Max     Guess   |   Min       Max     Guess   |
# --------------------------------------------------------------------------
#         0    382336         -         0    129216         -           0s
#         0    115377         -         0    122260         -           9s
#         0    115377         -         0    122260         -          11s
#         0    115377         -         0    122260         -          17s
#         0    103840         -         0    115381         -          22s
#         0    103840         -         0    115381         -          26s
#         0    103840         -         0    115381         -          32s
#         0    103840         -         0    115381         -          35s
#         0    103840         -         0    115381         -          42s
#         0    103840         -         0    115381         -          48s
#         0    103840         -         0    115381         -          53s
#         0    103840         -         0    115381         -          61s
#         0    103840         -         0    115381         -          67s
#         0     98648         -         0    111917         -          73s
#         0     98648         -         0    111917         -          78s
#         0     98648         -         0    111917         -          82s
#         0     98648         -         0    111917         -          87s
#         0     98648         -         0    111917         -          91s
#         0     98648         -         0    111917         -          99s
#         0     98648         -         0    111917         -         102s
#         0     98648         -         0    111917         -         107s
#         0     98648         -         0    111917         -         111s
#         0     88264         -         0    104911         -         116s
#         0     88264        20         0    104911         -         121s
#         0     88264        20         0    104911         -         126s
#         0     85668        20         0    102935         -         131s
#         0     85668        20         0    102935         -         136s
#         0     85668        20         0    102935         -         144s
#         0     85668        20         0    102935         -         145s
#         0     85668        20         0    102935         -         154s
#         0     83072        20         0    101156         -         159s
#         0     80476        20         0     99067         -         162s
#         0     77880        10         0     96935         -         167s
#         0     75284        10         0     94100         -         170s
#         0     75284        10         0     94100         -         176s
#         0     67496        10         0     87427         -         183s
#         0     67496        10         0     87427         -         185s
#         0     67496        10         0     87427         -         191s
#         0     67496        10         0     87427         -         196s
#         0     64900        10         0     84995         -         200s
#         0     64900        10         0     84995         -         206s
#         0     62304        23         0     81514         -         211s
#         0     62304        27         0     81514         -         215s
#         1     62303        29         0     81514         -         221s
#         1     59707        30         0     79288         -         225s
#         1     59707        32         0     79288         -         230s
#         1     59050        33         0     78441         -         235s
#         3     56447        34         0     76129         -         240s
#         5     55796        35         0     75432         -         245s
#         6     55140        36         0     74515         -         250s
#         9     51895        37         0     70625         -         255s
#        10     48650        37         0     67417         -         261s
#        13     47999        39         0     66654         -         266s
#        16     45402        39         0     63677         -         270s
#        19     45402        42         0     63677         -         275s
#        21     44748        45         0     62931         -         280s
#        21     44086        46         0     61818         -         285s
#        21     42781        46         0     60290         -         290s
#        23     37589        45         0     53433         -         295s
#        27     35642        48         0     51536         -         300s
#        28     35633        50         0     51206         -         305s
#        29     34325        50         0     49464         -         310s
#        34     31723        53         0     46451         -         315s
#        40     29775        57         0     43939         -         320s
#        46     26528        59         0     39836         -         325s
#        52     23282        63         0     36187         -         330s
#        59     19387        67         0     31019         -         335s
#        67     17437        74         0     28419         -         340s
#        74     12244        80         0     19514         -         345s
#        83      6403        84         0     11448         -         350s
#        84       648        86         0      1120         -         355s
#        85       137        87         0       247         -         360s
#        87       114        87         0       217         -         365s
#        87        87        87         0       139        10         370s
#        87        87        87         0        46        10         375s
#        87        87        87         8        21        11         380s
#        87        87        87        11        11        11         382s
#
# IIS computed: 87 constraints, 11 bounds
# IIS runtime: 381.93 seconds (191.88 work units)

# %%
m.write("model.ilp")
for constr in m.getConstrs():
    if constr.IISConstr:
        print(f"Constraint {constr.ConstrName} is in the IIS")
        # Print the linear expression of the constraint
        lhs = m.getRow(constr)
        rhs = constr.getAttr(GRB.Attr.RHS)
        sense = constr.Sense
        print(f"  LHS: {lhs}")
        print(f"  RHS: {rhs}")
        print(f"  Sense: {sense}")
# Out:
# Constraint Use Variable constraint[2023,Electricity,D3,BEV_S3_2023] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2023,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint[2023,Electricity,D3,BEV_S3_2024] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2024,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint[2023,Electricity,D3,BEV_S3_2028] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2028,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint[Electricity,2023,D3,BEV_S3_2025] is in the IIS
#   LHS: distance[BEV_S3_2025,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint[Electricity,2023,D3,BEV_S3_2026] is in the IIS
#   LHS: distance[BEV_S3_2026,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint[Electricity,2023,D3,BEV_S3_2027] is in the IIS
#   LHS: distance[BEV_S3_2027,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[BEV_S3_2029,2023,Electricity,D3] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2029,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[BEV_S3_2030,2023,Electricity,D3] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2030,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[BEV_S3_2031,2023,Electricity,D3] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2031,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[BEV_S3_2032,2023,Electricity,D3] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2032,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[BEV_S3_2036,2023,Electricity,D3] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2036,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[BEV_S3_2037,2023,Electricity,D3] is in the IIS
#   LHS: vehicle_list_fuels[BEV_S3_2037,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2024,2023,B20,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2024,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2025,2023,B20,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2025,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2025,2023,HVO,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2025,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2026,2023,HVO,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2026,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2027,2023,B20,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2027,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2027,2023,HVO,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2027,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2028,2023,B20,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2028,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2030,2023,B20,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2030,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2031,2023,HVO,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2031,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2034,2023,B20,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2034,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2034,2023,HVO,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2034,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2035,2023,HVO,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2035,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2037,2023,B20,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2037,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2037,2023,HVO,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2037,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2038,2023,B20,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2038,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[Diesel_S3_2038,2023,HVO,D3] is in the IIS
#   LHS: vehicle_list_fuels[Diesel_S3_2038,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2024,2023,BioLNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2024,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2024,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2024,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2026,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2026,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2027,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2027,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2028,2023,BioLNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2028,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2028,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2028,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2029,2023,BioLNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2029,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2029,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2029,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2030,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2030,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2031,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2031,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2032,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2032,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2033,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2033,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2034,2023,BioLNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2034,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2034,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2034,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2035,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2035,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2036,2023,BioLNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2036,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2037,2023,BioLNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2037,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2038,2023,BioLNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2038,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Use Variable constraint for Year Set[LNG_S3_2038,2023,LNG,D3] is in the IIS
#   LHS: vehicle_list_fuels[LNG_S3_2038,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[BEV_S3_2033,2023,Electricity,D3] is in the IIS
#   LHS: distance[BEV_S3_2033,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[BEV_S3_2034,2023,Electricity,D3] is in the IIS
#   LHS: distance[BEV_S3_2034,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[BEV_S3_2035,2023,Electricity,D3] is in the IIS
#   LHS: distance[BEV_S3_2035,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[BEV_S3_2038,2023,Electricity,D3] is in the IIS
#   LHS: distance[BEV_S3_2038,2023,Electricity,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2024,2023,HVO,D3] is in the IIS
#   LHS: distance[Diesel_S3_2024,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2026,2023,B20,D3] is in the IIS
#   LHS: distance[Diesel_S3_2026,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2028,2023,HVO,D3] is in the IIS
#   LHS: distance[Diesel_S3_2028,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2029,2023,B20,D3] is in the IIS
#   LHS: distance[Diesel_S3_2029,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2029,2023,HVO,D3] is in the IIS
#   LHS: distance[Diesel_S3_2029,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2030,2023,HVO,D3] is in the IIS
#   LHS: distance[Diesel_S3_2030,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2031,2023,B20,D3] is in the IIS
#   LHS: distance[Diesel_S3_2031,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2032,2023,B20,D3] is in the IIS
#   LHS: distance[Diesel_S3_2032,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2032,2023,HVO,D3] is in the IIS
#   LHS: distance[Diesel_S3_2032,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2033,2023,B20,D3] is in the IIS
#   LHS: distance[Diesel_S3_2033,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2033,2023,HVO,D3] is in the IIS
#   LHS: distance[Diesel_S3_2033,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2035,2023,B20,D3] is in the IIS
#   LHS: distance[Diesel_S3_2035,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2036,2023,B20,D3] is in the IIS
#   LHS: distance[Diesel_S3_2036,2023,B20,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[Diesel_S3_2036,2023,HVO,D3] is in the IIS
#   LHS: distance[Diesel_S3_2036,2023,HVO,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2025,2023,BioLNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2025,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2025,2023,LNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2025,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2026,2023,BioLNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2026,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2027,2023,BioLNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2027,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2030,2023,BioLNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2030,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2031,2023,BioLNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2031,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2032,2023,BioLNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2032,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2033,2023,BioLNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2033,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2035,2023,BioLNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2035,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2036,2023,LNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2036,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Distance constraint for Year Set[LNG_S3_2037,2023,LNG,D3] is in the IIS
#   LHS: distance[LNG_S3_2037,2023,LNG,D3]
#   RHS: 0.0
#   Sense: =
# Constraint Vehicle Mass Balance for 10 Years[Diesel_S3_2023] is in the IIS
#   LHS: -1.0 buy[Diesel_S3_2023] + sell[Diesel_S3_2023,2023] + sell[Diesel_S3_2023,2024] + sell[Diesel_S3_2023,2025] + sell[Diesel_S3_2023,2026] + sell[Diesel_S3_2023,2027] + sell[Diesel_S3_2023,2028] + sell[Diesel_S3_2023,2029]
#   RHS: 0.0
#   Sense: =
# Constraint Vehicle Mass Balance for 10 Years[LNG_S3_2023] is in the IIS
#   LHS: -1.0 buy[LNG_S3_2023] + sell[LNG_S3_2023,2023] + sell[LNG_S3_2023,2024] + sell[LNG_S3_2023,2025] + sell[LNG_S3_2023,2026] + sell[LNG_S3_2023,2027] + sell[LNG_S3_2023,2028] + sell[LNG_S3_2023,2029]
#   RHS: 0.0
#   Sense: =
# Constraint Vehicle Mass Balance for less than 10 Years[Diesel_S3_2023] is in the IIS
#   LHS: -1.0 buy[Diesel_S3_2023] + sell[Diesel_S3_2023,2030] + sell[Diesel_S3_2023,2031] + sell[Diesel_S3_2023,2032]
#   RHS: 0.0
#   Sense: =
# Constraint Vehicle Mass Balance for less than 10 Years[LNG_S3_2023] is in the IIS
#   LHS: -1.0 buy[LNG_S3_2023] + sell[LNG_S3_2023,2030] + sell[LNG_S3_2023,2031] + sell[LNG_S3_2023,2032]
#   RHS: 0.0
#   Sense: =
# Constraint Buy Sell Equality[Diesel_S3_2023,2036] is in the IIS
#   LHS: buy[Diesel_S3_2023] + -1.0 sell[Diesel_S3_2023,2023] + -1.0 sell[Diesel_S3_2023,2024] + -1.0 sell[Diesel_S3_2023,2025] + -1.0 sell[Diesel_S3_2023,2026] + -1.0 sell[Diesel_S3_2023,2027] + -1.0 sell[Diesel_S3_2023,2028] + -1.0 sell[Diesel_S3_2023,2029] + -1.0 sell[Diesel_S3_2023,2030] + -1.0 sell[Diesel_S3_2023,2031] + -1.0 sell[Diesel_S3_2023,2032] + -1.0 sell[Diesel_S3_2023,2033] + -1.0 sell[Diesel_S3_2023,2034] + -1.0 sell[Diesel_S3_2023,2035] + -1.0 vehicle_list[Diesel_S3_2023,2036]
#   RHS: 0.0
#   Sense: =
# Constraint Buy Sell Equality[LNG_S3_2023,2035] is in the IIS
#   LHS: buy[LNG_S3_2023] + -1.0 sell[LNG_S3_2023,2023] + -1.0 sell[LNG_S3_2023,2024] + -1.0 sell[LNG_S3_2023,2025] + -1.0 sell[LNG_S3_2023,2026] + -1.0 sell[LNG_S3_2023,2027] + -1.0 sell[LNG_S3_2023,2028] + -1.0 sell[LNG_S3_2023,2029] + -1.0 sell[LNG_S3_2023,2030] + -1.0 sell[LNG_S3_2023,2031] + -1.0 sell[LNG_S3_2023,2032] + -1.0 sell[LNG_S3_2023,2033] + -1.0 sell[LNG_S3_2023,2034] + -1.0 vehicle_list[LNG_S3_2023,2035]
#   RHS: 0.0
#   Sense: =
# Constraint Additonal Use Balance[Diesel_S3_2023,B20,D3,2023] is in the IIS
#   LHS: -8.0 buy[Diesel_S3_2023] + vehicle_list_fuels[Diesel_S3_2023,2023,B20,D3]
#   RHS: 0.0
#   Sense: <
# Constraint Additonal Use Balance[Diesel_S3_2023,HVO,D3,2023] is in the IIS
#   LHS: -8.0 buy[Diesel_S3_2023] + vehicle_list_fuels[Diesel_S3_2023,2023,HVO,D3]
#   RHS: 0.0
#   Sense: <
# Constraint Additonal Use Balance[LNG_S3_2023,LNG,D3,2023] is in the IIS
#   LHS: -8.0 buy[LNG_S3_2023] + vehicle_list_fuels[LNG_S3_2023,2023,LNG,D3]
#   RHS: 0.0
#   Sense: <
# Constraint Additonal Use Balance[LNG_S3_2023,BioLNG,D3,2023] is in the IIS
#   LHS: -8.0 buy[LNG_S3_2023] + vehicle_list_fuels[LNG_S3_2023,2023,BioLNG,D3]
#   RHS: 0.0
#   Sense: <

# %%
vehicle_distance['BEV_S2_2028']
# Out:
# 'D2'
